# %%
#read pickle file
import pickle
import pandas as pd
with open("../data/salary_guide.pkl", 'rb') as f:
     data = pickle.load(f)

#load to dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#            province                               job       entry  \
# 0           alberta          administrative assistant   43.6-56.4
# 1           alberta            administrative manager   65.2-74.3
# 2           alberta                   buyer assistant   45.5-57.2
# 3           alberta                 claims supervisor   70.1-82.0
# 4           alberta           contracts administrator   80.4-98.8
# ...             ...                               ...         ...
# 18600  saskatchewan               project coordinator   65.3-81.5
# 18601  saskatchewan  project manager (infrastructure)  95.9-130.1
# 18602  saskatchewan        project manager (software)  95.0-126.2
# 18603  saskatchewan                      scrum master   72.7-95.2
# 18604  saskatchewan                  technical writer   58.9-77.2
#
#                mid       senior
# 0        49.9-61.3    55.2-66.7
# 1        71.1-81.9    78.7-94.6
# 2        53.4-66.1    58.8-72.2
# 3       78.5-104.9   89.0-119.7
# ...
